# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['**', '###!', '####', '****', '*****', 'NULL']
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
# 5              52243               52243                INCIDENTE
# 6              50713               50713          INCIDENTE GRAVE
# 7              45334               45334                INCIDENTE
# 8              45391               45391                 ACIDENTE
# 9              52244               52244                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0           PORTO ALEGRE            RS                 SBPA     2012-01-06
# 1              GUARULHOS            SP                 SBGR     2012-01-06
# 2                 VIAMÃO            RS                  NaN     2012-01-06
# 3          SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 4               SÃO SEPÉ            RS                  NaN     2012-01-06
# 5                UBATUBA            SP                  NaN     2012-01-06
# 6               CAMPINAS            SP                 SDAI     2012-01-07
# 7                  BELÉM            PA                 SBBE     2012-01-08
# 8  CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 9             UBERLÂNDIA            MG                 SBUL     2012-01-08
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0
# 5        14:30:00                    0
# 6        18:15:00                    0
# 7        19:12:00                    0
# 8        16:00:00                    0
# 9        22:13:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_aerodromo':pa.Column(pa.String, nullable=True),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), #Declarando que podem existir campos nulos.
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-06
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                  NaN     2012-01-06
# 3        SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 4             SÃO SEPÉ            RS                  NaN     2012-01-06
# ...                ...           ...                  ...            ...
# 5162             JATAÍ            GO                  NaN     2021-12-30
# 5163           MARACAÍ            SP                  NaN     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5165          CURITIBA            PR                 SBBI     2021-12-31
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 1           13:44:00                    3
# 2           13:00:00                    0
# 3           17:00:00                    0
# 4           16:30:00                    0
# ...              ...                  ...
# 5162        20:30:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [5167 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         45331
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 1, dtype: object

# %%
df.iloc[-1] #(ultima linha)
# Out:
# codigo_ocorrencia                         80467
# codigo_ocorrencia2                        80467
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                     PETROLINA
# ocorrencia_uf                                PE
# ocorrencia_aerodromo                       SBPL
# ocorrencia_dia              2021-12-31 00:00:00
# ocorrencia_hora                        20:30:00
# total_recomendacoes                           0
# Name: 5166, dtype: object

# %%
df.iloc[10:15] #esse resultado trará apenas até o 14, diferentemente do df.loc que se baseia no label.
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 11              52245               52245                INCIDENTE
# 12              45396               45396          INCIDENTE GRAVE
# 13              45408               45408                 ACIDENTE
# 14              45447               45447                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                  NaN     2012-01-09
# 11      PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12            MARABÁ            PA                 SBMA     2012-01-11
# 13          ELDORADO            SP                  NaN     2012-01-11
# 14        RIO BRANCO            AC                  NaN     2012-01-13
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 11        13:36:00                    0
# 12        11:21:00                    0
# 13        13:45:00                    1
# 14        18:15:00                    0

# %%
df.loc[:,'ocorrencia_uf']
# Out:
# 0       RS
# 1       SP
# 2       RS
# 3       SP
# 4       RS
#         ..
# 5162    GO
# 5163    SP
# 5164    RS
# 5165    PR
# 5166    PE
# Name: ocorrencia_uf, Length: 5167, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RS
# 1       SP
# 2       RS
# 3       SP
# 4       RS
#         ..
# 5162    GO
# 5163    SP
# 5164    RS
# 5165    PR
# 5166    PE
# Name: ocorrencia_uf, Length: 5167, dtype: object

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.ocorrencia_uf.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5162    False
# 5163    False
# 5164    False
# 5165    False
# 5166    False
# Name: ocorrencia_uf, Length: 5167, dtype: bool

# %%
df.loc[df.ocorrencia_uf.isnull()]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1099              49474               49474                 ACIDENTE
# 4728              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1099  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 4728      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 1099        02:54:00                    0
# 4728        11:00:00                    0

# %%
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1099              49474               49474                 ACIDENTE
# 4728              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1099  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 4728      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 1099        02:54:00                    0
# 4728        11:00:00                    0

# %%
df.count()
# Out:
# codigo_ocorrencia           5167
# codigo_ocorrencia2          5167
# ocorrencia_classificacao    5167
# ocorrencia_cidade           5167
# ocorrencia_uf               5165
# ocorrencia_aerodromo        3262
# ocorrencia_dia              5167
# ocorrencia_hora             5166
# total_recomendacoes         5167
# dtype: int64

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 844               47938               47938                INCIDENTE
# 1669              52265               52265                 ACIDENTE
# 2804              66432               66432          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 844           BRASÍLIA            DF                 SBBR     2013-04-13
# 1669            SANTOS            SP                  NaN     2014-08-13
# 2804           VITÓRIA            ES                  NaN     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes
# 844         18:00:00                   11
# 1669        13:03:00                   13
# 2804        11:47:00                   12

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro, 'ocorrencia_cidade']
# Out:
# 844     BRASÍLIA
# 1669      SANTOS
# 2804     VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#      ocorrencia_cidade  total_recomendacoes
# 844           BRASÍLIA                   11
# 1669            SANTOS                   13
# 2804           VITÓRIA                   12

# %%
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 12                45396               45396          INCIDENTE GRAVE
# 18                50714               50714          INCIDENTE GRAVE
# 19                45399               45399          INCIDENTE GRAVE
# 24                45582               45582          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5139              80427               80427          INCIDENTE GRAVE
# 5146              80448               80448          INCIDENTE GRAVE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5164              80457               80457          INCIDENTE GRAVE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                CAMPINAS            SP                 SDAI     2012-01-07
# 12                 MARABÁ            PA                 SBMA     2012-01-11
# 18                CAMOCIM            CE                 SNWC     2012-01-17
# 19                  MUANÁ            PA                  NaN     2012-01-18
# 24           RONDONÓPOLIS            MT                 SWRD     2012-01-20
# ...                   ...           ...                  ...            ...
# 5139    NOVA BANDEIRANTES            MT                  NaN     2021-12-12
# 5146  FORMOSO DO ARAGUAIA            TO                  NaN     2021-12-18
# 5158            ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159           SANTA RITA            PB                  NaN     2021-12-29
# 5164        NOVO HAMBURGO            RS                 SSNH     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 12          11:21:00                    0
# 18          18:25:00                    0
# 19          17:35:00                    0
# 24          17:00:00                    0
# ...              ...                  ...
# 5139        17:20:00                    0
# 5146        19:00:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5164        11:59:00                    0
#
# [691 rows x 9 columns]

# %%
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro1 = df.ocorrencia_uf == 'SP'
df.loc[filtro, filtro1]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
#       2 filtro1 = df.ocorrencia_uf == 'SP'
# ----> 3 df.loc[filtro, filtro1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1182, in _LocIndexer._getitem_axis(self, key, axis)
#    1180     return self._get_slice_axis(key, axis=axis)
#    1181 elif com.is_bool_indexer(key):
# -> 1182     return self._getbool_axis(key, axis=axis)
#    1183 elif is_list_like_indexer(key):
#    1184
#    1185     # an iterable multi-selection
#    1186     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:984, in _LocationIndexer._getbool_axis(self, key, axis)
#     981 def _getbool_axis(self, key, axis: int):
#     982     # caller is responsible for ensuring non-None axis
#     983     labels = self.obj._get_axis(axis)
# --> 984     key = check_bool_indexer(labels, key)
#     985     inds = key.nonzero()[0]
#     986     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:2383, in check_bool_indexer(index, key)
#    2381     mask = isna(result._values)
#    2382     if mask.any():
# -> 2383         raise IndexingError(
#    2384             "Unalignable boolean Series provided as "
#    2385             "indexer (index of the boolean Series and of "
#    2386             "the indexed object do not match)."
#    2387         )
#    2388     return result.astype(bool)._values
#    2389 if is_object_dtype(key):
#    2390     # key might be object-dtype bool, check_array_indexer needs bool array
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
#filtros: combinando 2 filtros: classificacao == 'INCIDENTE GRAVE' E UF == 'SP'
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2] #operador logico AND
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 78                45598               45598          INCIDENTE GRAVE
# 86                45653               45653          INCIDENTE GRAVE
# 91                45599               45599          INCIDENTE GRAVE
# 140               45651               45651          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 4954              80200               80200          INCIDENTE GRAVE
# 4980              80238               80238          INCIDENTE GRAVE
# 5003              80265               80265          INCIDENTE GRAVE
# 5098              80382               80382          INCIDENTE GRAVE
# 5158              80454               80454          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6              CAMPINAS            SP                 SDAI     2012-01-07
# 78    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-20
# 86            GUARULHOS            SP                 SBGR     2012-02-24
# 91    BRAGANÇA PAULISTA            SP                 SBBP     2012-02-27
# 140                 ITU            SP                  NaN     2012-03-24
# ...                 ...           ...                  ...            ...
# 4954  BRAGANÇA PAULISTA            SP                 SDVH     2021-07-25
# 4980        VOTUPORANGA            SP                 SDVG     2021-08-11
# 5003          SÃO PAULO            SP                 SBMT     2021-08-31
# 5098         PIRACICABA            SP                 SDPW     2021-11-16
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 78          14:10:00                    0
# 86          20:04:00                    0
# 91          19:15:00                    0
# 140         20:45:00                    1
# ...              ...                  ...
# 4954        12:25:00                    0
# 4980        19:09:00                    0
# 5003        16:50:00                    0
# 5098        20:50:00                    0
# 5158        21:35:00                    0
#
# [132 rows x 9 columns]

# %%
#filtros: combinando 2 filtros: classificacao == 'INCIDENTE GRAVE' OU UF == 'SP'
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2] #operador logico OR
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 45331               45331                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 12                45396               45396          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 3        SÃO SEBASTIÃO            SP                  NaN     2012-01-06
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 12              MARABÁ            PA                 SBMA     2012-01-11
# ...                ...           ...                  ...            ...
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159        SANTA RITA            PB                  NaN     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
# 5163           MARACAÍ            SP                  NaN     2021-12-31
# 5164     NOVO HAMBURGO            RS                 SSNH     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 1           13:44:00                    3
# 3           17:00:00                    0
# 5           14:30:00                    0
# 6           18:15:00                    0
# 12          11:21:00                    0
# ...              ...                  ...
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5161        13:15:00                    0
# 5163        09:30:00                    0
# 5164        11:59:00                    0
#
# [1820 rows x 9 columns]

# %%
#filtros classificacao == 'INCIDENTE GRAVE' OU 'INCIDENTE' E UF == 'SP'
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 28                52248               52248                INCIDENTE
# 35                52054               52054                INCIDENTE
# 36                52055               52055                INCIDENTE
# ...                 ...                 ...                      ...
# 5134              80425               80425                INCIDENTE
# 5143              80431               80431                INCIDENTE
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 28           SÃO PAULO            SP                 SBMT     2012-01-21
# 35           SÃO PAULO            SP                 SBMT     2012-01-25
# 36      RIBEIRÃO PRETO            SP                  NaN     2012-01-25
# ...                ...           ...                  ...            ...
# 5134         SÃO PAULO            SP                 SBSP     2021-12-09
# 5143            SANTOS            SP                 SBST     2021-12-15
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
#
#      ocorrencia_hora  total_recomendacoes
# 5           14:30:00                    0
# 6           18:15:00                    0
# 28          11:15:00                    0
# 35          23:00:00                    0
# 36          09:30:00                    0
# ...              ...                  ...
# 5134        20:30:00                    0
# 5143        12:30:00                    0
# 5157        09:00:00                    0
# 5158        21:35:00                    0
# 5161        13:15:00                    0
#
# [913 rows x 9 columns]

# %%
#filtros: facilitando com o metodo isin() que verifica possibilidades dentro de uma coluna
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 28                52248               52248                INCIDENTE
# 35                52054               52054                INCIDENTE
# 36                52055               52055                INCIDENTE
# ...                 ...                 ...                      ...
# 5134              80425               80425                INCIDENTE
# 5143              80431               80431                INCIDENTE
# 5157              80453               80453                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5161              80456               80456                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5              UBATUBA            SP                  NaN     2012-01-06
# 6             CAMPINAS            SP                 SDAI     2012-01-07
# 28           SÃO PAULO            SP                 SBMT     2012-01-21
# 35           SÃO PAULO            SP                 SBMT     2012-01-25
# 36      RIBEIRÃO PRETO            SP                  NaN     2012-01-25
# ...                ...           ...                  ...            ...
# 5134         SÃO PAULO            SP                 SBSP     2021-12-09
# 5143            SANTOS            SP                 SBST     2021-12-15
# 5157          CAMPINAS            SP                 SBKP     2021-12-29
# 5158         ARAÇATUBA            SP                 SBAU     2021-12-29
# 5161         SÃO PAULO            SP                 SBSP     2021-12-30
#
#      ocorrencia_hora  total_recomendacoes
# 5           14:30:00                    0
# 6           18:15:00                    0
# 28          11:15:00                    0
# 35          23:00:00                    0
# 36          09:30:00                    0
# ...              ...                  ...
# 5134        20:30:00                    0
# 5143        12:30:00                    0
# 5157        09:00:00                    0
# 5158        21:35:00                    0
# 5161        13:15:00                    0
#
# [913 rows x 9 columns]

# %%
#filtro parcial: Trazer todas as cidades que comecem com a letra C
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 50713               50713          INCIDENTE GRAVE
# 8                 45391               45391                 ACIDENTE
# 15                45409               45409                 ACIDENTE
# 18                50714               50714          INCIDENTE GRAVE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5142              80434               80434                 ACIDENTE
# 5144              80447               80447                INCIDENTE
# 5150              80445               80445                 ACIDENTE
# 5157              80453               80453                INCIDENTE
# 5165              80460               80460                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                  CAMPINAS            SP                 SDAI     2012-01-07
# 8     CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 15                  CÁCERES            MT                  NaN     2012-01-14
# 18                  CAMOCIM            CE                 SNWC     2012-01-17
# 22        CACHOEIRA DOURADA            GO                  NaN     2012-01-20
# ...                     ...           ...                  ...            ...
# 5142                CARACOL            MS                  NaN     2021-12-14
# 5144                CONFINS            MG                 SBCF     2021-12-15
# 5150            CHUPINGUAIA            RO                  NaN     2021-12-20
# 5157               CAMPINAS            SP                 SBKP     2021-12-29
# 5165               CURITIBA            PR                 SBBI     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:15:00                    0
# 8           16:00:00                    0
# 15          10:00:00                    0
# 18          18:25:00                    0
# 22          21:00:00                    0
# ...              ...                  ...
# 5142        21:35:00                    0
# 5144        17:10:00                    0
# 5150        12:05:00                    0
# 5157        09:00:00                    0
# 5165        15:12:00                    0
#
# [771 rows x 9 columns]

# %%
#filtro parcial: Trazer todas as cidades que termine com a letra A
# obs: str[-1] serve para buscar a primeira letra de uma string (atraves do indice)
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 52243               52243                INCIDENTE
# 9                 52244               52244                INCIDENTE
# 17                52246               52246                INCIDENTE
# 21                45392               45392                 ACIDENTE
# 22                45390               45390                 ACIDENTE
# ...                 ...                 ...                      ...
# 5152              80465               80465                INCIDENTE
# 5158              80454               80454          INCIDENTE GRAVE
# 5159              80455               80455          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5               UBATUBA            SP                  NaN     2012-01-06
# 9            UBERLÂNDIA            MG                 SBUL     2012-01-08
# 17             BRASÍLIA            DF                 SBBR     2012-01-16
# 21             BRASÍLIA            DF                  NaN     2012-01-19
# 22    CACHOEIRA DOURADA            GO                  NaN     2012-01-20
# ...                 ...           ...                  ...            ...
# 5152            VITÓRIA            ES                 SBVT     2021-12-21
# 5158          ARAÇATUBA            SP                 SBAU     2021-12-29
# 5159         SANTA RITA            PB                  NaN     2021-12-29
# 5165           CURITIBA            PR                 SBBI     2021-12-31
# 5166          PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5           14:30:00                    0
# 9           22:13:00                    0
# 17          16:47:00                    0
# 21          21:30:00                    2
# 22          21:00:00                    0
# ...              ...                  ...
# 5152        22:25:00                    0
# 5158        21:35:00                    0
# 5159        18:50:00                    0
# 5165        15:12:00                    0
# 5166        20:30:00                    0
#
# [1386 rows x 9 columns]

# %%
#filtro parcial: Trazer todas as cidades que termine com as letras NA
filtro = df.ocorrencia_cidade.str[-2:] == 'NA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 51                45587               45587                 ACIDENTE
# 52                52056               52056                INCIDENTE
# 54                45572               45572                 ACIDENTE
# 113               45612               45612                INCIDENTE
# 172               45750               45750                 ACIDENTE
# ...                 ...                 ...                      ...
# 5040              80311               80311                 ACIDENTE
# 5045              80323               80323                INCIDENTE
# 5068              80348               80348                 ACIDENTE
# 5100              80394               80394                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 51          CORRENTINA            BA                  NaN     2012-02-05
# 52            LONDRINA            PR                 SBLO     2012-02-05
# 54           PALESTINA            SP                  NaN     2012-02-06
# 113           LONDRINA            PR                 SBLO     2012-03-10
# 172          ITIRAPINA            SP                  NaN     2012-04-13
# ...                ...           ...                  ...            ...
# 5040           VILHENA            RO                  NaN     2021-09-29
# 5045          TERESINA            PI                 SBTE     2021-10-08
# 5068           VILHENA            RO                  NaN     2021-10-24
# 5100          TERESINA            PI                 SBTE     2021-11-17
# 5166         PETROLINA            PE                 SBPL     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 51          20:27:00                    0
# 52          17:34:00                    0
# 54          19:30:00                    0
# 113         16:35:00                    0
# 172         15:45:00                    0
# ...              ...                  ...
# 5040        15:10:00                    0
# 5045        16:20:00                    0
# 5068        18:40:00                    0
# 5100        14:40:00                    0
# 5166        20:30:00                    0
#
# [237 rows x 9 columns]

# %%
#filtro parcial: Trazer todas as cidades que contem as letras MA
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 12                45396               45396          INCIDENTE GRAVE
# 16                45693               45693                INCIDENTE
# 45                45682               45682                INCIDENTE
# 59                45580               45580          INCIDENTE GRAVE
# 79                45715               45715                INCIDENTE
# ...                 ...                 ...                      ...
# 5138              80428               80428                 ACIDENTE
# 5153              80461               80461                INCIDENTE
# 5156              80463               80463                INCIDENTE
# 5160              80451               80451                INCIDENTE
# 5163              80452               80452                 ACIDENTE
#
#             ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 12                     MARABÁ            PA                 SBMA
# 16                      MACAÉ            RJ                  NaN
# 45                      MACAÉ            RJ                  NaN
# 59                      MACAÉ            RJ                  NaN
# 79                     MANAUS            AM                 SWFN
# ...                       ...           ...                  ...
# 5138  SANTA VITÓRIA DO PALMAR            RS                  NaN
# 5153                  MARINGÁ            PR                 SBMG
# 5156                  MARINGÁ            PR                 SBMG
# 5160                   MANAUS            AM                 SBEG
# 5163                  MARACAÍ            SP                  NaN
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 12       2012-01-11        11:21:00                    0
# 16       2012-01-14        10:30:00                    0
# 45       2012-02-01        13:50:00                    0
# 59       2012-02-07        14:50:00                    4
# 79       2012-02-20        09:10:00                    0
# ...             ...             ...                  ...
# 5138     2021-12-11        19:40:00                    0
# 5153     2021-12-24        03:30:00                    0
# 5156     2021-12-28        16:11:00                    0
# 5160     2021-12-30        14:41:00                    0
# 5163     2021-12-31        09:30:00                    0
#
# [423 rows x 9 columns]

# %%
#filtro parcial com operador logico OR: Trazer todas as cidades que contem as letras MA OU AL
filtro = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 8                 45391               45391                 ACIDENTE
# 11                52245               52245                INCIDENTE
# 12                45396               45396          INCIDENTE GRAVE
# 16                45693               45693                INCIDENTE
# ...                 ...                 ...                      ...
# 5153              80461               80461                INCIDENTE
# 5154              80468               80468                INCIDENTE
# 5156              80463               80463                INCIDENTE
# 5160              80451               80451                INCIDENTE
# 5163              80452               80452                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0              PORTO ALEGRE            RS                 SBPA     2012-01-06
# 8     CONCEIÇÃO DAS ALAGOAS            MG                  NaN     2012-01-08
# 11             PORTO ALEGRE            RS                 SBPA     2012-01-09
# 12                   MARABÁ            PA                 SBMA     2012-01-11
# 16                    MACAÉ            RJ                  NaN     2012-01-14
# ...                     ...           ...                  ...            ...
# 5153                MARINGÁ            PR                 SBMG     2021-12-24
# 5154               SALVADOR            BA                 SBSV     2021-12-26
# 5156                MARINGÁ            PR                 SBMG     2021-12-28
# 5160                 MANAUS            AM                 SBEG     2021-12-30
# 5163                MARACAÍ            SP                  NaN     2021-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           20:27:00                    0
# 8           16:00:00                    0
# 11          13:36:00                    0
# 12          11:21:00                    0
# 16          10:30:00                    0
# ...              ...                  ...
# 5153        03:30:00                    0
# 5154        16:56:00                    0
# 5156        16:11:00                    0
# 5160        14:41:00                    0
# 5163        09:30:00                    0
#
# [791 rows x 9 columns]

# %%
#filtro parcial: ocorrencia do ano de 2015
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1870              52992               52992          INCIDENTE GRAVE
# 1871              52979               52979                 ACIDENTE
# 1872              53073               53073                INCIDENTE
# 1873              53074               53074                INCIDENTE
# 1874              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
# 2338              60642               60642                INCIDENTE
# 2339              60631               60631                 ACIDENTE
# 2340              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1870              SALVADOR            BA                 SBSV     2015-01-01
# 1871              IVINHEMA            MS                  NaN     2015-01-02
# 1872                  TEFÉ            AM                 SBTF     2015-01-02
# 1873        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 1874                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 2336               ITABERÁ            SP                  NaN     2015-12-24
# 2337             GUARULHOS            SP                 SBGR     2015-12-25
# 2338  SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 2339             MAÇAMBARÁ            RS                  NaN     2015-12-28
# 2340            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 1870        11:40:00                    3
# 1871        14:50:00                    0
# 1872        16:28:00                    0
# 1873        20:34:00                    0
# 1874        22:04:00                    6
# ...              ...                  ...
# 2336        14:00:00                    0
# 2337        19:00:00                    0
# 2338        16:00:00                    0
# 2339        19:00:00                    2
# 2340        14:00:00                    0
#
# [471 rows x 9 columns]

# %%
#filtro parcial: ocorrencia do ano de 2015 e mes 12
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2302              53573               53573                INCIDENTE
# 2303              60601               60601                INCIDENTE
# 2304              53634               53634                INCIDENTE
# 2305              53636               53636                INCIDENTE
# 2306              53575               53575                INCIDENTE
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
# 2314              53627               53627                INCIDENTE
# 2315              60604               60604                INCIDENTE
# 2316              60611               60611                INCIDENTE
# 2317              60613               60613                 ACIDENTE
# 2318              60629               60629                 ACIDENTE
# 2319              53630               53630                INCIDENTE
# 2320              60603               60603                INCIDENTE
# 2321              60612               60612                 ACIDENTE
# 2322              60783               60783                 ACIDENTE
# 2323              53639               53639                INCIDENTE
# 2324              60609               60609          INCIDENTE GRAVE
# 2325              60616               60616                 ACIDENTE
# 2326              60620               60620                 ACIDENTE
# 2327              60645               60645                 ACIDENTE
# 2328              60608               60608                INCIDENTE
# 2329              60625               60625                 ACIDENTE
# 2330              60605               60605                INCIDENTE
# 2331              60610               60610                INCIDENTE
# 2332              60602               60602                INCIDENTE
# 2333              60615               60615                INCIDENTE
# 2334              60640               60640                INCIDENTE
# 2335              60641               60641                INCIDENTE
# 2336              60632               60632          INCIDENTE GRAVE
# 2337              60600               60600                INCIDENTE
# 2338              60642               60642                INCIDENTE
# 2339              60631               60631                 ACIDENTE
# 2340              60649               60649                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 
AXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 2310        14:30:00                    1
# 2311        10:20:00                    0
# 2312        16:19:00                    0
# 2313        13:00:00                    0

# %%
#filtro parcial: ocorrencia do ano de 2015 e mes 12 e do dia 3 ao 8
filtro_ano = df.ocorrencia_dia.dt.year == 2015
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia = (df.ocorrencia_dia.dt.day >=3) & (df.ocorrencia_dia.dt.day <=8)
df.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2306              53575               53575                INCIDENTE
# 2307              60637               60637                INCIDENTE
# 2308              53625               53625                 ACIDENTE
# 2309              53626               53626                 ACIDENTE
# 2310              53628               53628                 ACIDENTE
# 2311              53629               53629          INCIDENTE GRAVE
# 2312              53631               53631                INCIDENTE
# 2313              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2306  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 2307         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 2308               TRINDADE            GO                  NaN     2015-12-06
# 2309              AMERICANA            SP                 SDAI     2015-12-06
# 2310                  AGUAÍ            SP                  NaN     2015-12-08
# 2311                  JALES            SP                 SDJL     2015-12-08
# 2312               CAMPINAS            SP                 SBKP     2015-12-08
# 2313          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 2306        10:50:00                    0
# 2307        16:47:00                    0
# 2308        13:10:00                    3
# 2309        15:00:00                    1
# 2310        14:30:00                    1
# 2311        10:20:00                    0
# 2312        16:19:00                    0
# 2313        13:00:00                    0

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           52242.0            52242.0                INCIDENTE
# 1           45331.0            45331.0                 ACIDENTE
# 2           45333.0            45333.0                 ACIDENTE
# 3           45401.0            45401.0                 ACIDENTE
# 4           45407.0            45407.0                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA  2012-01-06 00:00:00
# 1         GUARULHOS            SP                 SBGR  2012-01-06 00:00:00
# 2            VIAMÃO            RS                  NaN  2012-01-06 00:00:00
# 3     SÃO SEBASTIÃO            SP                  NaN  2012-01-06 00:00:00
# 4          SÃO SEPÉ            RS                  NaN  2012-01-06 00:00:00
#
#   ocorrencia_hora total_recomendacoes ocorrencia_dia_hora
# 0        20:27:00                 0.0 2012-01-06 20:27:00
# 1        13:44:00                 3.0 2012-01-06 13:44:00
# 2        13:00:00                 0.0 2012-01-06 13:00:00
# 3        17:00:00                 0.0 2012-01-06 17:00:00
# 4        16:30:00                 0.0 2012-01-06 16:30:00

# %%
#filtro parcial: ocorrencia do ano de 2015 e mes 12 e do dia 3 as 11:00 ao dia 8 13:00
filtro1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'
df.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 2307           60637.0            60637.0                INCIDENTE
# 2308           53625.0            53625.0                 ACIDENTE
# 2309           53626.0            53626.0                 ACIDENTE
# 2311           53629.0            53629.0          INCIDENTE GRAVE
# 2313           60636.0            60636.0                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
